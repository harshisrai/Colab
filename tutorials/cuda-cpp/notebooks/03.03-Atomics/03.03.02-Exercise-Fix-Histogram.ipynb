# %% [markdown]
# <a href="https://colab.research.google.com/github/harshisrai/Colab/blob/main/tutorials/cuda-cpp/notebooks/03.03-Atomics/03.03.02-Exercise-Fix-Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercise: Fix Histogram
#
# The code below has a data race in it.
# Multiple threads concurrently increment the same element of the histogram array.
# Use `cuda::std::atomic_ref` to fix this bug.
#
# Interface of `cuda::std::atomic_ref` is equivalent to `std::atomic_ref`:
#
# ```c++
# __global__ void kernel(int *count)
# {
#   // Wrap data in atomic_ref
#   cuda::std::atomic_ref<int> ref(count[0]);
#
#   // Atomically increment the underlying value
#   ref.fetch_add(1);
# }
# ```

# %%
import os

if os.getenv("COLAB_RELEASE_TAG"): # If running in Google Colab:
  # !mkdir -p Sources
  # !wget https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.03-Atomics/Sources/ach.cuh -nv -O Sources/ach.cuh
  # !wget https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.03-Atomics/Sources/__init__.py -nv -O Sources/__init__.py
  # !wget https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.03-Atomics/Sources/ach.py -nv -O Sources/ach.py
# Out:
# 2026-05-16 02:43:24 URL:https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.03-Atomics/Sources/ach.cuh [5873/5873] -> "Sources/ach.cuh" [1]
# 2026-05-16 02:43:25 URL:https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.03-Atomics/Sources/__init__.py [19/19] -> "Sources/__init__.py" [1]
# 2026-05-16 02:43:25 URL:https://raw.githubusercontent.com/NVIDIA/accelerated-computing-hub/refs/heads/main/tutorials/cuda-cpp/notebooks/03.03-Atomics/Sources/ach.py [3786/3786] -> "Sources/ach.py" [1]

# %% [markdown]
# <details>
# <summary>Original code in case you need to refer to it.</summary>
#
# ```c++
# %%writefile Sources/histogram.cpp
# #include "ach.cuh"
#
# constexpr float bin_width = 10;
#
# __global__ void histogram_kernel(cuda::std::span<float> temperatures,
#                                  cuda::std::span<int> histogram)
# {
#   int cell = blockIdx.x * blockDim.x + threadIdx.x;
#   if (cell < temperatures.size()) {
#     int bin = static_cast<int>(temperatures[cell] / bin_width);
#
#     // fix data race in incrementing histogram bins by using `cuda::std::atomic_ref`
#     int old_count = histogram[bin];
#     int new_count = old_count + 1;
#     histogram[bin] = new_count;
#   }
# }
#
# void histogram(cuda::std::span<float> temperatures,
#                cuda::std::span<int> histogram,
#                cudaStream_t stream)
# {
#   int block_size = 256;
#   int grid_size = cuda::ceil_div(temperatures.size(), block_size);
#   histogram_kernel<<<grid_size, block_size, 0, stream>>>(
#     temperatures, histogram);
# }
# ```
#
# </details>

# %%
# %%writefile Sources/histogram.cpp
# #include "ach.cuh"
#
# constexpr float bin_width = 10;
#
# __global__ void histogram_kernel(cuda::std::span<float> temperatures,
#                                  cuda::std::span<int> histogram)
# {
#   int cell = blockIdx.x * blockDim.x + threadIdx.x;
#   if (cell < temperatures.size()) {
#     int bin = static_cast<int>(temperatures[cell] / bin_width);
#
#     // TODO: fix data race in incrementing histogram bins by using `cuda::std::atomic_ref`
#     cuda::std::atomic_ref<int> ref(histogram[bin]);
#     ref.fetch_add(1);
#   }
# }
#
# void histogram(cuda::std::span<float> temperatures,
#                cuda::std::span<int> histogram,
#                cudaStream_t stream)
# {
#   int block_size = 256;
#   int grid_size = cuda::ceil_div(temperatures.size(), block_size);
#   histogram_kernel<<<grid_size, block_size, 0, stream>>>(
#     temperatures, histogram);
# }
# Out:
# Overwriting Sources/histogram.cpp

# %%
pip install jupyter_dark_detect
# Out:
# Collecting jupyter_dark_detect
#   Downloading jupyter_dark_detect-0.1.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: ipython>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from jupyter_dark_detect) (7.34.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=7.0.0->jupyter_dark_detect)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.0.0->jupyter_dark_detect) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.0.0->jupyter_dark_detect) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.0.0->jupyter_dark_detect) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.0.0->jupyter_dark_detect) (0.6.0)
# Downloading jupyter_dark_detect-0.1.0-py3-none-any.whl (8.0 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 111.1 MB/s eta 0:00:00
# Installing collected packages: jedi, jupyter_dark_detect
# Successfully installed jedi-0.20.0 jupyter_dark_detect-0.1.0

# %%
import Sources.ach
Sources.ach.run("Sources/histogram.cpp")
# Out:
# <video width="800" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# If you’re unsure how to proceed, consider expanding this section for guidance. Use the hint only after giving the problem a genuine attempt.
#
# <details>
#   <summary>Hints</summary>
#
#   - `cuda::std::atomic_ref` wraps a reference and applies atomic operations to the underlying object
#   - You can increment a variable atomically using `ref.fetch_add(1)`
# </details>

# %% [markdown]
# Open this section only after you’ve made a serious attempt at solving the problem. Once you’ve completed your solution, compare it with the reference provided here to evaluate your approach and identify any potential improvements.
#
# <details>
#   <summary>Solution</summary>
#
#   Key points:
#
#   - Wrap selected bin in `cuda::std::atomic_ref<int>` for atomic operations
#   - Use `fetch_add` to increment the bin value atomically
#
#   Solution:
#   ```c++
#   __global__ void histogram_kernel(cuda::std::span<float> temperatures,
#                                    cuda::std::span<int> histogram)
#   {
#     int cell = blockIdx.x * blockDim.x + threadIdx.x;
#     int bin = static_cast<int>(temperatures[cell] / 10);
#
#     cuda::std::atomic_ref<int> ref(histogram[bin]);
#     ref.fetch_add(1);
#   }
#   ```
#
#   You can find full solution [here](Solutions/histogram.cpp).
# </details>

# %% [markdown]
# ---
# Congratulations!  Move on to the [next section](../03.04-Synchronization/03.04.01-Sync.ipynb)
